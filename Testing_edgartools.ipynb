# %%
pip install edgartools
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 13.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 59.9 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 68.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 37.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: textdistance
#     Found existing installation: textdistance 4.2.1
#     Uninstalling textdistance-4.2.1:
# ...

# %%
from edgar import *

# Tell the SEC who you are
set_identity("erinyyu3@gmail.com")

filings = get_filings()
# Out:
# /Users/erinyu/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# [15:35:50] INFO     Identity of the Edgar REST client set to [erinyyu3@gmail.com]                       ]8;id=10142;file:///Users/erinyu/anaconda3/lib/python3.11/site-packages/edgar/core.py\core.py]8;;\:]8;id=314765;file:///Users/erinyu/anaconda3/lib/python3.11/site-packages/edgar/core.py#154\154]8;;\

# %%
filings = get_filings(year=range(2012, 2023),form="10-Q")
filings

df = filings.to_pandas()

# %%
df
# Out:
#           form                                company      cik filing_date  \
# 0         10-Q                           Energem Corp  1879373  2021-12-30
# 1         10-Q                          Linktory Inc.  1867956  2021-12-30
# 2         10-Q                            NEOGEN CORP   711377  2021-12-30
# 3         10-Q           QMIS TBS Capital Group Corp.  1796160  2021-12-30
# 4         10-Q                    Umatrin Holding Ltd  1317839  2021-12-30
# ...        ...                                    ...      ...         ...
# 220314  10-Q/A                    RAZOR RESOURCES INC  1333614  2012-01-03
# 220315  10-Q/A         Solar Energy Initiatives, Inc.  1421665  2012-01-03
# 220316  10-Q/A  Spring Creek Healthcare Systems, Inc.  1366823  2012-01-03
# 220317  10-Q/A  Spring Creek Healthcare Systems, Inc.  1366823  2012-01-03
# 220318  10-Q/A  Spring Creek Healthcare Systems, Inc.  1366823  2012-01-03
#
#             accession_number
# 0       0001493152-21-032779
# ...
